# %%
import random

def get_name(nums:int=2)->list[str]:
    with open('/workspaces/__2024_10_22__gjun_ai__/lesson9/names.txt',mode='r',encoding='utf-8') as file:
        names_str = file.read()
    names = names_str.split()
    names = random.choices(names,k=nums)
    return  names

def generate_bmi(names:list[str])->list[dict]:
    students:list[dict] = []
    for name in names:
        height = random.randint(140,190)
        weight = random.randint(50,110)
        BMI = weight / ((height/100)**2)
        if BMI >= 35:
            status = "重度肥胖"
        elif BMI >= 30:
            status = "中度肥胖"
        elif BMI >= 27:
            status = "輕度肥胖"
        elif BMI >= 24:
            status = "過重"
        elif BMI >= 18.5:
            status = "正常範圍"
        else:
            status = "體重過輕"
        student = {
            '姓名':name,
            '身高':height,
            '體重':weight,
            'BMI':round(BMI,2),
            '狀態':status
        }
        students.append(student)
    return students


nums = int(input('請輸入人數:'))
names:list[str] = get_name(nums=nums)
students:list[dict] = generate_bmi(names=names)
for student in students:
    for key,value in student.items():
        print(f'{key}:{value}')
    print("==================")
# Out:
# 姓名:林康亮
# 身高:150
# 體重:83
# BMI:36.89
# 狀態:重度肥胖
# ==================
# 姓名:李美洋
# 身高:171
# 體重:95
# BMI:32.49
# 狀態:中度肥胖
# ==================
# 姓名:盧必妍
# 身高:179
# 體重:72
# BMI:22.47
# 狀態:正常範圍
# ==================
# 姓名:蕭怡伶
# 身高:179
# 體重:57
# BMI:17.79
# 狀態:體重過輕
# ==================
# 姓名:陳姵彬
# 身高:170
# 體重:72
# BMI:24.91
# 狀態:過重
# ==================
# 姓名:林佳蓉
# 身高:169
# 體重:87
# BMI:30.46
# 狀態:中度肥胖
# ==================
# 姓名:黃柏宇
# 身高:154
# 體重:110
# BMI:46.38
# 狀態:重度肥胖
# ==================
# 姓名:黃奎紹
# 身高:144
# 體重:71
# BMI:34.24
# 狀態:中度肥胖
# ==================
# 姓名:林佳慧
# 身高:142
# 體重:87
# BMI:43.15
# 狀態:重度肥胖
# ==================
# 姓名:龐皓芳
# 身高:184
# 體重:57
# BMI:16.84
# 狀態:體重過輕
# ==================
