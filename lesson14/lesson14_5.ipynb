# %%
import numpy as np
import pandas as pd

scores =np.random.randint(50,101,size=(50,5))
df1 = pd.DataFrame(scores,
                   columns=['國文', '英文', '數學', '地理', '歷史'],
                   index = range(1,51))

df1
# Out:
#     國文  英文   數學   地理   歷史
# 1   54  57   75   91   69
# 2   95  88   80   90   50
# 3   85  67   70   81   68
# 4   90  98   90   77   60
# 5   92  58   52   85  100
# 6   55  67   84   59   96
# 7   80  53   91   54   72
# 8   63  55   93   73   69
# 9   83  62   50   71   70
# 10  62  90   72   97   99
# 11  85  67   75   84   95
# 12  55  54   91   70   77
# 13  93  51   92   65   75
# 14  88  70   69   72   62
# 15  61  93   77   93   57
# 16  90  79   50   76   93
# 17  99  79   79   65   73
# 18  83  53   65   63   81
# 19  62  78   93   96   83
# 20  53  54  100   70   97
# 21  67  90   87   62   97
# 22  86  73   52   75   60
# 23  54  87   71  100   68
# 24  71  70   92   92   53
# 25  98  50   99   93   74
# 26  79  96   64   88   58
# 27  74  60   90   71   76
# 28  51  66   63   63   73
# 29  61  96   55   75   90
# 30  86  53   52   72   93
# 31  64  67   63  100   74
# 32  91  61   55   60   85
# 33  88  57   72   66   99
# 34  78  85   98   63   91
# ...

# %%
df1.index.name = '學號'
df1.columns.name = "科目"

# %%
df1.loc[1].sum()
# Out:
# np.int64(346)

# %%
sum = df1.sum(axis=1)

average = sum /5

# %%
df1['總分'] = sum
df1['平均'] = average
df1
# Out:
# 科目  國文  英文   數學   地理   歷史   總分    平均
# 學號
# 1   54  57   75   91   69  346  69.2
# 2   95  88   80   90   50  403  80.6
# 3   85  67   70   81   68  371  74.2
# 4   90  98   90   77   60  415  83.0
# 5   92  58   52   85  100  387  77.4
# 6   55  67   84   59   96  361  72.2
# 7   80  53   91   54   72  350  70.0
# 8   63  55   93   73   69  353  70.6
# 9   83  62   50   71   70  336  67.2
# 10  62  90   72   97   99  420  84.0
# 11  85  67   75   84   95  406  81.2
# 12  55  54   91   70   77  347  69.4
# 13  93  51   92   65   75  376  75.2
# 14  88  70   69   72   62  361  72.2
# 15  61  93   77   93   57  381  76.2
# 16  90  79   50   76   93  388  77.6
# 17  99  79   79   65   73  395  79.0
# 18  83  53   65   63   81  345  69.0
# 19  62  78   93   96   83  412  82.4
# 20  53  54  100   70   97  374  74.8
# 21  67  90   87   62   97  403  80.6
# 22  86  73   52   75   60  346  69.2
# 23  54  87   71  100   68  380  76.0
# 24  71  70   92   92   53  378  75.6
# ...

# %%
english = df1['英文'] < 60
df1[english]
# Out:
# 科目  國文  英文   數學  地理   歷史   總分    平均
# 學號
# 1   54  57   75  91   69  346  69.2
# 5   92  58   52  85  100  387  77.4
# 7   80  53   91  54   72  350  70.0
# 8   63  55   93  73   69  353  70.6
# 12  55  54   91  70   77  347  69.4
# 13  93  51   92  65   75  376  75.2
# 18  83  53   65  63   81  345  69.0
# 20  53  54  100  70   97  374  74.8
# 25  98  50   99  93   74  414  82.8
# 30  86  53   52  72   93  356  71.2
# 33  88  57   72  66   99  382  76.4
# 37  90  59   92  95   54  390  78.0
# 38  56  52   70  52   58  288  57.6
# 42  57  57   79  72   59  324  64.8
# 43  65  59   94  82   65  365  73.0
# 48  74  55   58  83   89  359  71.8
