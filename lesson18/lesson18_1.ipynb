# %%
import os
current_folder = os.getcwd()
stations_folder = os.path.join(current_folder,'stations')
csv_abs_files = []
for filename in os.listdir(stations_folder):
    if '每日各站' in filename:
        csv_abs_files.append(os.path.join(stations_folder,filename))

csv_abs_files
# Out:
# ['/workspaces/__2024_10_22__gjun_ai__/lesson18/stations/每日各站進出站人數2023.csv',
#  '/workspaces/__2024_10_22__gjun_ai__/lesson18/stations/每日各站進出站人數2021.csv',
#  '/workspaces/__2024_10_22__gjun_ai__/lesson18/stations/每日各站進出站人數2020.csv',
#  '/workspaces/__2024_10_22__gjun_ai__/lesson18/stations/每日各站進出站人數20190423-20191231.csv',
#  '/workspaces/__2024_10_22__gjun_ai__/lesson18/stations/每日各站進出站人數2022.csv']

# %%
import pandas as pd
station_df = pd.read_csv(csv_abs_files[0])

# %%
info_path = os.path.join(stations_folder,'台鐵車站資訊.csv')
info_df = pd.read_csv(info_path)

# %%
merge_df = pd.merge(station_df, info_df,how='left',left_on='staCode',right_on='stationCode')
merge_df
# Out:
#        trnOpDate  staCode  gateInComingCnt  gateOutGoingCnt  stationCode  \
# 0       20230101      900             8030             8241          900
# 1       20230101      910             1017             1326          910
# 2       20230101      920             1400             1705          920
# 3       20230101      930             3558             4398          930
# 4       20230101      940             1509             1815          940
# ...          ...      ...              ...              ...          ...
# 86604   20231231     7360             7916             8252         7360
# 86605   20231231     7361              164              195         7361
# 86606   20231231     7362              652              720         7362
# 86607   20231231     7380             1526              656         7380
# 86608   20231231     7390              576              447         7390
#
#       stationName name                                  stationAddrTw  \
# 0              基隆   基隆                                    基隆市仁愛區港西街5號
# 1              三坑   三坑                             基隆市仁愛區德厚里龍安街 206 號
# 2              八堵   八堵                             基隆市暖暖區八南里八堵路 142 號
# 3              七堵   七堵                               基隆市七堵區長興里東新街 2 號
# 4              百福   百福                          基隆市七堵區堵南里明德三路 1 之 1 號
# ...           ...  ...                                            ...
# 86604          瑞芳   瑞芳                            新北市瑞芳區龍潭里明燈路三段 82 號
# 86605         海科館  海科館                                      基隆市中正區長潭里
# 86606         八斗子  八斗子  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
# 86607         四腳亭  四腳亭                              新北市瑞芳區吉慶里中央路 65 號
# 86608          暖暖   暖暖                              基隆市暖暖區暖暖里暖暖街 51 號
#
#         stationTel                 gps haveBike
# 0      02-24263743  25.13411 121.73997        Y
# 1      02-24230289  25.12305 121.74202        Y
# 2      02-24560841  25.10843 121.72898        Y
# 3      02-24553426  25.09294 121.71415        Y
# 4      02-24528372  25.07795 121.69379        N
# ...            ...                 ...      ...
# 86604  02-24972033  25.10861 121.80596        Y
# 86605  02-24972033  25.13754 121.79997        N
# 86606  02-24972033  25.13545 121.80261        N
# 86607  02-24579346  25.10283 121.76192        N
# 86608  02-24972033  25.10224 121.74048        N
#
# [86609 rows x 11 columns]
